# %% [markdown]
# <a href="https://colab.research.google.com/github/InsightByHarshit/TrendsettersAnalytics/blob/main/Dress.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings

# Suppress a specific warning
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file1 = '/content/drive/MyDrive/Colab Notebooks/Dress/Attribute+DataSet.csv'

attribute_data = pd.read_csv(file1)

# %%
attribute_data.head()
# Out:
#      Dress_ID    Style    Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6    M  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0    L  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0    L  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6    L  Spring   o-neck         full
# 4   876339541     cute      Low     4.5    M  Summer   o-neck    butterfly
#
#         Material FabricType  Decoration Pattern Type  Recommendation
# 0            NaN    chiffon     ruffles       animal               1
# 1     microfiber        NaN     ruffles       animal               0
# 2       polyster        NaN         NaN        print               0
# 3           silk    chiffon  embroidary        print               1
# 4  chiffonfabric    chiffon         bow          dot               0

# %%
# Checking for data types
attribute_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 479 entries, 0 to 478
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Dress_ID        479 non-null    int64
#  1   Style           479 non-null    object
#  2   Price           477 non-null    object
#  3   Rating          479 non-null    float64
#  4   Size            479 non-null    object
#  5   Season          477 non-null    object
#  6   NeckLine        476 non-null    object
#  7   SleeveLength    477 non-null    object
#  8   Material        360 non-null    object
#  9   FabricType      223 non-null    object
#  10  Decoration      255 non-null    object
#  11  Pattern Type    377 non-null    object
#  12  Recommendation  479 non-null    int64
# dtypes: float64(1), int64(2), object(10)
# memory usage: 48.8+ KB

# %%
# Checking for missing values and data types in both datasets
attribute_data.isnull().sum()
# Out:
# Dress_ID            0
# Style               0
# Price               2
# Rating              0
# Size                0
# Season              2
# NeckLine            3
# SleeveLength        2
# Material          119
# FabricType        256
# Decoration        224
# Pattern Type      102
# Recommendation      0
# dtype: int64

# %%
# Summary statistics for numerical columns
attribute_data.describe()
# Out:
#            Dress_ID      Rating  Recommendation
# count  4.790000e+02  479.000000      479.000000
# mean   9.022420e+08    3.489353        0.427975
# std    1.822352e+08    2.028941        0.495302
# min    1.234568e+08    0.000000        0.000000
# 25%    7.666611e+08    2.000000        0.000000
# 50%    9.096250e+08    4.600000        0.000000
# 75%    1.039684e+09    4.800000        1.000000
# max    1.253973e+09    5.000000        1.000000

# %% [markdown]
# # **Univariate Analysis Scenarios**

# %%
#Count of Unique Values for Each Column
print("Unique Values:\n", attribute_data.nunique())
# Out:
# Unique Values:
#  Dress_ID          479
# Style              13
# Price               5
# Rating             17
# Size                7
# Season              7
# NeckLine           16
# SleeveLength       17
# Material           22
# FabricType         22
# Decoration         24
# Pattern Type       14
# Recommendation      2
# dtype: int64

# %%
#Size Distribution
if 'Size' in attribute_data.columns:
    attribute_data['Size'].value_counts().plot(kind='pie', autopct='%1.1f%%')
    plt.title('Size Distribution')
    plt.show()

# %%
# Most Common Material
if 'Material' in attribute_data.columns:
    print("Most Common Material:", attribute_data['Material'].mode()[0])
# Out:
# Most Common Material: cotton

# %%
# 7. Style Popularity
attribute_data['Style'].value_counts().plot(kind='bar', color='purple')
plt.title('Style Popularity')
plt.show()

# %%
# 8. Season Distribution
if 'Season' in attribute_data.columns:
    attribute_data['Season'].value_counts().plot(kind='pie', autopct='%1.1f%%')
    plt.title('Season Distribution')
    plt.show()

# %%
# 12. Recommendation Status Distribution
attribute_data['Recommendation'].value_counts().plot(kind='bar', color='orange')
plt.title('Recommendation Status')
plt.xlabel('Recommendation (0=No, 1=Yes)')
plt.ylabel('Count')
plt.show()

# %%
# 15. Attribute Completeness
completeness = (1 - attribute_data.isnull().sum() / len(attribute_data)) * 100
print("Attribute Completeness (%):\n", completeness)
# Out:
# Attribute Completeness (%):
#  Dress_ID          100.000000
# Style             100.000000
# Price              99.582463
# Rating            100.000000
# Size              100.000000
# Season             99.582463
# NeckLine           99.373695
# SleeveLength       99.582463
# Material           75.156576
# FabricType         46.555324
# Decoration         53.235908
# Pattern Type       78.705637
# Recommendation    100.000000
# dtype: float64

# %% [markdown]
# # **BIVARIATE ANALYSIS**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'attribute_data' is your DataFrame

# Create a cross-tabulation of Style and Material
style_material_crosstab = pd.crosstab(attribute_data['Style'], attribute_data['Material'])

# Plot the stacked bar chart
style_material_crosstab.plot(kind='bar', stacked=True, figsize=(12, 4))
plt.title('Style vs Material')
plt.xlabel('Style')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels if needed
plt.legend(title='Material', bbox_to_anchor=(1.05, 1), loc='best')  # Place legend outside the plot
plt.tight_layout()
plt.show()

# %%
# 17. Size vs Ratings
if {'Size', 'Ratings'}.issubset(attribute_data.columns):
    sns.boxplot(data=attribute_data, x='Size', y='Ratings')
    plt.title('Size vs Ratings')
    plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(data=attribute_data, x='Size', y='Rating')
plt.title('Size vs Ratings')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'attribute_data' is your DataFrame and contains 'Season' and 'Recommendation' columns

# Create the grouped bar chart using seaborn
sns.countplot(x='Season', hue='Recommendation', data=attribute_data)
plt.title('Season vs Recommendation')
plt.xlabel('Season')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.legend(title='Recommendation', labels=['Not Recommended (0)', 'Recommended (1)'])
plt.show()

# %%
# Example: Ratings by Style and Occasion
if {'Style', 'Ratings', 'Occasion'}.issubset(attribute_data.columns):
    plt.figure(figsize=(10, 6))
    sns.barplot(data=attribute_data, x='Style', y='Ratings', hue='Occasion')
    plt.title('Ratings by Style and Occasion')
    plt.show()

# %% [markdown]
# # **MULTIVARIATE ANALYSIS**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a pivot table to aggregate ratings by style and season
style_season_ratings = attribute_data.pivot_table(values='Rating', index='Style', columns='Season', aggfunc='mean')

# Create the heatmap using seaborn
plt.figure(figsize=(8, 4))  # Adjust figure size if needed
sns.heatmap(style_season_ratings, annot=True, cmap='viridis', fmt=".2f")  # Annotate with values, choose colormap
plt.title('Average Ratings by Style and Season')
plt.xlabel('Season')
plt.ylabel('Style')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

# Load the dataset

file='/content/drive/MyDrive/Colab Notebooks/Dress/Attribute+DataSet.csv'
data = pd.read_csv(file)

# Handle missing data (optional, for cleaner analysis)
data.fillna("Unknown", inplace=True)

# Set a general style for visualizations
sns.set(style="whitegrid")

# Univariate Analysis
# 1. Analyze the distribution of ratings
plt.figure(figsize=(8, 5))
sns.histplot(data['Rating'], kde=True, bins=10, color='blue')
plt.title("Distribution of Ratings")
plt.xlabel("Rating")
plt.ylabel("Frequency")
plt.show()

# 2. Frequency distribution of styles
plt.figure(figsize=(10, 6))
data['Style'].value_counts().plot(kind='bar', color='purple')
plt.title("Frequency Distribution of Styles")
plt.xlabel("Style")
plt.ylabel("Count")
plt.show()

# 3. Proportion of recommendations
plt.figure(figsize=(6, 6))
data['Recommendation'].value_counts().plot(kind='pie', autopct='%1.1f%%', labels=["Not Recommended", "Recommended"], colors=['red', 'green'])
plt.title("Proportion of Recommendations")
plt.show()

# 4. Distribution of dress sizes
plt.figure(figsize=(8, 5))
sns.countplot(x=data['Size'], palette='viridis')
plt.title("Distribution of Dress Sizes")
plt.xlabel("Size")
plt.ylabel("Count")
plt.show()

# 5. Count of each price category
plt.figure(figsize=(8, 5))
data['Price'].value_counts().plot(kind='bar', color='orange')
plt.title("Count of Each Price Category")
plt.xlabel("Price")
plt.ylabel("Count")
plt.show()

# 6. Count of dresses by season
plt.figure(figsize=(8, 5))
data['Season'].value_counts().plot(kind='bar', color='teal')
plt.title("Count of Dresses by Season")
plt.xlabel("Season")
plt.ylabel("Count")
plt.show()

# 7. Analysis of missing values in Material
missing_materials = data['Material'].value_counts()
plt.figure(figsize=(8, 5))
missing_materials.plot(kind='bar', color='pink')
plt.title("Distribution of Material")
plt.xlabel("Material")
plt.ylabel("Count")
plt.show()

# 8. Analyze the occurrence of different necklines
plt.figure(figsize=(10, 6))
data['NeckLine'].value_counts().plot(kind='bar', color='cyan')
plt.title("Occurrence of Different Necklines")
plt.xlabel("NeckLine")
plt.ylabel("Count")
plt.show()

# 9. Identify the most common fabric types
plt.figure(figsize=(10, 6))
data['FabricType'].value_counts().plot(kind='bar', color='lime')
plt.title("Most Common Fabric Types")
plt.xlabel("Fabric Type")
plt.ylabel("Count")
plt.show()

# 10. Count of unique dress IDs
unique_dress_ids = data['Dress_ID'].nunique()
print(f"Number of unique dress IDs: {unique_dress_ids}")

# Bivariate Analysis
# 1. Relationship between price and recommendation
plt.figure(figsize=(8, 5))
sns.countplot(x=data['Price'], hue=data['Recommendation'], palette='coolwarm')
plt.title("Relationship between Price and Recommendation")
plt.xlabel("Price")
plt.ylabel("Count")
plt.show()

# 2. Ratings by season
plt.figure(figsize=(8, 5))
sns.boxplot(x=data['Season'], y=data['Rating'], palette='muted')
plt.title("Ratings by Season")
plt.xlabel("Season")
plt.ylabel("Rating")
plt.show()

# 3. Average rating for each style
average_rating_style = data.groupby('Style')['Rating'].mean().sort_values()
plt.figure(figsize=(10, 6))
average_rating_style.plot(kind='bar', color='violet')
plt.title("Average Rating for Each Style")
plt.xlabel("Style")
plt.ylabel("Average Rating")
plt.show()

# 4. Size distribution across price categories
plt.figure(figsize=(8, 5))
sns.countplot(x=data['Size'], hue=data['Price'], palette='Set2')
plt.title("Size Distribution across Price Categories")
plt.xlabel("Size")
plt.ylabel("Count")
plt.show()

# 5. Effect of neckline type on recommendation
plt.figure(figsize=(10, 6))
sns.countplot(x=data['NeckLine'], hue=data['Recommendation'], palette='husl')
plt.title("Effect of Neckline Type on Recommendation")
plt.xlabel("NeckLine")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# 6. Rating comparison between seasons
plt.figure(figsize=(8, 5))
sns.violinplot(x=data['Season'], y=data['Rating'], palette='cool')
plt.title("Rating Comparison between Seasons")
plt.xlabel("Season")
plt.ylabel("Rating")
plt.show()

# 7. Correlation between ratings and recommendations
correlation = data[['Rating', 'Recommendation']].corr()
print("Correlation between Ratings and Recommendations:\n", correlation)

# 8. Material vs. Recommendation distribution
plt.figure(figsize=(10, 6))
sns.countplot(x=data['Material'], hue=data['Recommendation'], palette='Set1')
plt.title("Material vs. Recommendation Distribution")
plt.xlabel("Material")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# 9. Decoration vs. Recommendation counts
plt.figure(figsize=(10, 6))
sns.countplot(x=data['Decoration'], hue=data['Recommendation'], palette='Dark2')
plt.title("Decoration vs. Recommendation Counts")
plt.xlabel("Decoration")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# 10. Pattern type vs. Recommendation analysis
plt.figure(figsize=(10, 6))
sns.countplot(x=data['Pattern Type'], hue=data['Recommendation'], palette='Accent')
plt.title("Pattern Type vs. Recommendation Analysis")
plt.xlabel("Pattern Type")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# 11. Neckline vs. Average rating
average_rating_neckline = data.groupby('NeckLine')['Rating'].mean().sort_values()
plt.figure(figsize=(10, 6))
average_rating_neckline.plot(kind='bar', color='skyblue')
plt.title("Average Rating by Neckline")
plt.xlabel("NeckLine")
plt.ylabel("Average Rating")
plt.xticks(rotation=45)
plt.show()

# 12. Sleeve length vs. Recommendation
plt.figure(figsize=(10, 6))
sns.countplot(x=data['SleeveLength'], hue=data['Recommendation'], palette='coolwarm')
plt.title("Sleeve Length vs. Recommendation")
plt.xlabel("Sleeve Length")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# 13. Season vs. Fabric type counts
plt.figure(figsize=(10, 6))
sns.countplot(x=data['Season'], hue=data['FabricType'], palette='cubehelix')
plt.title("Season vs. Fabric Type Counts")
plt.xlabel("Season")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# 14. Style vs. Recommendation proportions
style_recommendation = pd.crosstab(data['Style'], data['Recommendation'], normalize='index')
style_recommendation.plot(kind='bar', stacked=True, figsize=(10, 6), colormap='viridis')
plt.title("Style vs. Recommendation Proportions")
plt.xlabel("Style")
plt.ylabel("Proportion")
plt.show()

# 15. Price vs. Ratings
plt.figure(figsize=(8, 5))
sns.boxplot(x=data['Price'], y=data['Rating'], palette='pastel')
plt.title("Price vs. Ratings")
plt.xlabel("Price")
plt.ylabel("Rating")
plt.show()

# Multivariate Analysis
# 1. Influence of style, price, and season on recommendations
plt.figure(figsize=(12, 6))
sns.violinplot(x=data['Style'], y=data['Rating'], hue=data['Recommendation'], split=True, palette='Set2')
plt.title("Influence of Style, Price, and Season on Recommendations")
plt.xlabel("Style")
plt.ylabel("Rating")
plt.xticks(rotation=45)
plt.show()

# 2. Ratings across combinations of size and season
plt.figure(figsize=(12, 6))
sns.boxplot(x=data['Size'], y=data['Rating'], hue=data['Season'], palette='coolwarm')
plt.title("Ratings across Combinations of Size and Season")
plt.xlabel("Size")
plt.ylabel("Rating")
plt.show()

# 3. Cluster analysis of price, style, and recommendations
encoder = LabelEncoder()
data_encoded = data[['Price', 'Style', 'Recommendation']].apply(encoder.fit_transform)
sns.pairplot(data_encoded, hue='Recommendation', palette='husl')
plt.title("Cluster Analysis of Price, Style, and recommendations")
plt.show()
# Out:
# <ipython-input-6-fe0139ea8b2b>:46: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=data['Size'], palette='viridis')
# Number of unique dress IDs: 479
# <ipython-input-6-fe0139ea8b2b>:108: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=data['Season'], y=data['Rating'], palette='muted')
# <ipython-input-6-fe0139ea8b2b>:142: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x=data['Season'], y=data['Rating'], palette='cool')
# Correlation between Ratings and Recommendations:
#                    Rating  Recommendation
# ...
